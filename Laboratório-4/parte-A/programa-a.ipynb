# %%
import numpy as np
import cv2 as cv
KERNEL_LENGTHS = [3,5,11,29]

img = cv.imread('foto-geral.jpg',1)
cv.imshow('image',img)
k = cv.waitKey(0)
if k == 27:         # wait for ESC key to exit
    cv.destroyAllWindows()
elif k == ord('s'): # wait for 's' key to save and exit
    for j in KERNEL_LENGTHS:
        for i in range(1, j, 2):
            dst = cv.blur(img, (i, i))
        cv.imwrite(f"blur_kernel{j}x{j}",dst)
        cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 14
#      12 for i in range(1, j, 2):
#      13     dst = cv.blur(img, (i, i))
# ---> 14 cv.imwrite(f'blur_kernel{j}x{j}',dst)
#      15 cv.destroyAllWindows()
#
# error: OpenCV(4.13.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:1072: error: (-2:Unspecified error) could not find a writer for the specified extension in function 'imwrite_'

# %%
import numpy as np
import cv2 as cv
KERNEL_LENGTHS = [3,5,11,29]

img = cv.imread('foto-geral.jpg',1)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.blur(img, (i, i))
    file_name = f"imagens/foto_geral_blur_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.GaussianBlur(img, (i, i), 0)
    file_name = f"imagens/foto_geral_gaussian_blur_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.medianBlur(img, i)
    file_name = f"imagens/foto_geral_median_blur_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.bilateralFilter(img, i, i * 2, i / 2)
    file_name = f"imagens/foto_geral_bilateral_filter_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)

# %%
import numpy as np
import cv2 as cv
KERNEL_LENGTHS = [3,5,11,29]

img = cv.imread('foto_avatar.png',1)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.blur(img, (i, i))
    file_name = f"imagens/foto_avatar_blur_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.GaussianBlur(img, (i, i), 0)
    file_name = f"imagens/foto_avatar_gaussian_blur_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.medianBlur(img, i)
    file_name = f"imagens/foto_avatar_median_blur_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)
    
for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.bilateralFilter(img, i, i * 2, i / 2)
    file_name = f"imagens/foto_avatar_bilateral_filter_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)

# %%
import cv2
import numpy as np
 
def add_gaussian_noise(image, mean=0, std=25):
    noise = np.random.normal(mean, std, image.shape).astype(np.uint8)
    noisy_image = cv2.add(image, noise)
    return noisy_image
 
original_image = cv2.imread('foto-geral.jpg')
 
if original_image is None:
    raise Exception("Image not loaded properly. Check the file path.")
 
noisy_image = add_gaussian_noise(original_image, mean=0, std=30)
 
#cv2.imshow("Original Image", original_image)
cv2.imshow("Noisy Image", noisy_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite("imagens/imagem-teste-ruido-gaussiano.jpg", noisy_image)
# Out:
# True

# %%
import cv2
import numpy as np
 
 
def add_salt_and_pepper_noise(image, noise_ratio=0.02):
    noisy_image = image.copy()
    h, w, c = noisy_image.shape
    noisy_pixels = int(h * w * noise_ratio)
 
    for _ in range(noisy_pixels):
        row, col = np.random.randint(0, h), np.random.randint(0, w)
        if np.random.rand() < 0.5:
            noisy_image[row, col] = [0, 0, 0] 
        else:
            noisy_image[row, col] = [255, 255, 255]
 
    return noisy_image

 
original_image = cv2.imread('foto-geral.jpg')
 
if original_image is None:
    raise Exception("Image not loaded properly. Check the file path.")
 
noisy_image = add_salt_and_pepper_noise(original_image, noise_ratio=0.2)

 
#cv2.imshow("Original Image", original_image)
cv2.imshow("Noisy Image (Salt and Pepper)", noisy_image)

cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite("imagens/imagem-teste-ruido-sal-e-pimenta.jpg", noisy_image)
# Out:
# True

# %%
import numpy as np
import cv2 as cv
import os

def add_gaussian_noise(image, mean=0, std=25):
    noise = np.random.normal(mean, std, image.shape).astype(np.uint8)
    noisy_image = cv2.add(image, noise)
    return noisy_image

def add_salt_and_pepper_noise(image, noise_ratio=0.02):
    noisy_image = image.copy()
    h, w, c = noisy_image.shape
    noisy_pixels = int(h * w * noise_ratio)
 
    for _ in range(noisy_pixels):
        row, col = np.random.randint(0, h), np.random.randint(0, w)
        if np.random.rand() < 0.5:
            noisy_image[row, col] = [0, 0, 0] 
        else:
            noisy_image[row, col] = [255, 255, 255]
 
    return noisy_image

original = cv.imread('foto-geral.jpg')
img_gauss = add_gaussian_noise(original)
img_sp = add_salt_and_pepper_noise(original)

cv.imwrite('imagens/ruido_gaussiano.jpg', img_gauss)
cv.imwrite('imagens/ruido_sal_pimenta.jpg', img_sp)

denoised = cv.medianBlur(img_sp, 5)
psnr_val = cv.PSNR(original, denoised)

print(f"PSNR do Filtro Mediana no ruído Sal e Pimenta: {psnr_val:.2f} dB")
# Out:
# PSNR do Filtro Mediana no ruído Sal e Pimenta: 33.16 dB

# %%
import cv2 as cv

cap = cv.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    melhor = cv.medianBlur(frame, 5)
    pior = cv.blur(frame, (29, 29))

    cv.imshow('Melhor Filtro', melhor)
    cv.imshow('Pior Filtro', pior)

    key = cv.waitKey(1) & 0xFF
    if key == ord('s'):
        cv.imwrite('imagens/captura_webcam_melhor.jpg', melhor)
        cv.imwrite('imagens/captura_webcam_pior.jpg', pior)
    elif key == ord('q'):
        break

cap.release()
cv.destroyAllWindows()
# Out:
# Imagens salvas!
