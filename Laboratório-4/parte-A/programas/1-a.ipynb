# %%
import numpy as np
import cv2 as cv
KERNEL_LENGTHS = [3,5,11,29]

img = cv.imread('../imagens/foto-geral.jpg',1)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.blur(img, (i, i))
    file_name = f"../imagens/foto_geral_blur_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.GaussianBlur(img, (i, i), 0)
    file_name = f"../imagens/foto_geral_gaussian_blur_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.medianBlur(img, i)
    file_name = f"../imagens/foto_geral_median_blur_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.bilateralFilter(img, i, i * 2, i / 2)
    file_name = f"../imagens/foto_geral_bilateral_filter_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)

# %%
import numpy as np
import cv2 as cv
KERNEL_LENGTHS = [3,5,11,29]

img = cv.imread('../imagens/foto_avatar.png',1)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.blur(img, (i, i))
    file_name = f"../imagens/foto_avatar_blur_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.GaussianBlur(img, (i, i), 0)
    file_name = f"../imagens/foto_avatar_gaussian_blur_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)

for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.medianBlur(img, i)
    file_name = f"../imagens/foto_avatar_median_blur_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)
    
for j in KERNEL_LENGTHS:
    for i in range(1, j, 2):
        dst = cv.bilateralFilter(img, i, i * 2, i / 2)
    file_name = f"../imagens/foto_avatar_bilateral_filter_kernel{j}x{j}.jpeg"
    cv.imwrite(file_name, dst)
